# %% [markdown]
# ## Requirements

# %% [markdown]
# - Designers like to go to design talks and share knowledge. There must be some nearby companies that also do design.
# - 30% of the company have at least 1 child.
# - Developers like to be near successful tech startups that have raised at least 1 Million dollars.
# - Executives like Starbucks A LOT. Ensure there's a starbucks not to far.
# - Account managers need to travel a lot
# - All people in the company have between 25 and 40 years, give them some place to go to party.
# - Nobody in the company likes to have companies with more than 10 years in a radius of 2 KM.
# - The CEO is Vegan

# %%
from pymongo import MongoClient
import folium
import pandas as pd

# %% [markdown]
# Function to conect to the database and collection of MongoDB in localhost:

# %%
def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

# %% [markdown]
# Function to get the latitude and longitude in geoJSON format:

# %%
db, coll = connectCollection('companies','companies')

# %%
def getLocation(comp,i):
    latitude = comp['offices'][i]['latitude']
    longitude = comp['offices'][i]['longitude']
    loc = {
        'type':'Point',
        'coordinates':[longitude, latitude]
    }
    return loc

# %% [markdown]
# Let's find all the companies that have less than 10 years since their foundation:

# %%
company = coll.find({"$and": [{"total_money_raised": {"$gt": "$1M"}},{"founded_year": {"$gt":2009}}]})

# %% [markdown]
# Now I set a new field in the documents, call "location", which will contain the info provided by getLocation function:

# %%
for c in company:
    for i in range(len(c['offices'])):
        value = {"$set": {'offices.'+str(i)+'.location':getLocation(c,i)}}
        coll.update_one(c,value)

# %%
for c in company:
    for i in range(len(c['offices'])):
        value = {"$set": {'location.'+str(i):getLocation(c,i)}}
        coll.update_one(c,value)

# %%
for c in company:
    for i in range(len(c['offices'])):
        value = {"$unset": {'location'+str(i):''}}
        coll.update_one(c,value)

# %%
company = coll.find({"$and": [{"total_money_raised": {"$gt": "$1M"}},{"founded_year": {"$gt":2009}}]})

# %%
df = pd.DataFrame(list(company))

# %%
df = df.drop(columns=['overview','image','products','acquisitions','blog_url','blog_feed_url','twitter_username','founded_month','founded_day','deadpooled_month','deadpooled_day','deadpooled_url','alias_list','email_address','phone_number','created_at','updated_at'])

# %%
new_df = df[['name','category_code','number_of_employees','founded_year','deadpooled_year','tag_list','description','total_money_raised']]

# %%
new_df
# Out:
#                      name category_code  number_of_employees  founded_year  \
# 0                CircleUp       finance                 11.0          2011
# 1                   GENWI        mobile                 25.0          2010
# 2                   Fixya           web                 30.0          2013
# 3                   Wamba           web                120.0          2013
# 4              RazorGator     ecommerce                  NaN          2011
# 5                 Skydeck        mobile                  9.0          2012
# 6                 Moblica        mobile                  NaN          2011
# 7                 Magento     ecommerce                275.0          2010
# 8                  Pixsta           web                  NaN          2010
# 9             FirstString        search                  NaN          2011
# 10               Localist           web                  7.0          2010
# 11              Integrate      software                120.0          2010
# 12                 vufind        mobile                  7.0          2010
# 13             UsingMiles        travel                 15.0          2010
# 14               Cellogic        mobile                  8.0          2010
# 15                  Kidos   games_video                  NaN          2011
# 16               Localist           web                  7.0          2010
# 17              Integrate      software                120.0          2010
# 18                 vufind        mobile                  7.0          2010
# 19             UsingMiles        travel                 15.0          2010
# 20               Cellogic        mobile                  8.0          2010
# 21                  Kidos   games_video                  NaN          2011
# 22                 Webtab        mobile                  NaN          2010
# 23                Diffbot     analytics                  6.0          2010
# 24                  Yipit           web                 23.0          2010
# 25                Queralt    enterprise                  7.0          2011
# 26              FeedHenry    enterprise                 30.0          2010
# 27         Avenir Medical       biotech                  NaN          2010
# 28                Twitpay     ecommerce                  5.0          2010
# 29               VisualOn      software                  NaN          2011
# 30                AppNeta      software                  NaN          2010
# 31                MyLikes   advertising                  NaN          2010
# 32                Tongxue           web                  NaN          2013
# 33                 Jobzle         other                  5.0          2010
# 34  Insignia Technologies   hospitality                  NaN          2012
# 35                 Blurtt           web                  5.0          2010
# 36                Fliptop    enterprise                 16.0          2010
# 37          Red Ambiental     cleantech                  NaN          2012
# 38              Chicisimo       fashion                  4.0          2010
# 39  VistaGen Therapeutics       biotech                  NaN          2013
# 40               ticketea     ecommerce                  NaN          2010
# 41                DocASAP           web                  7.0          2012
#
#     deadpooled_year                                           tag_list  \
# 0               NaN  crowdfunding, angel-investing, private-equity,...
# 1               NaN  mcms, mobile-content-management-system, live-a...
# 2               NaN  fixya, crowdsourcing, diy, repair, customer-se...
# 3               NaN                                      socialnetwork
# 4               NaN  ticketreselling, onlineauctions, onlineexchang...
# 5               NaN  photo-sharing, photography, messaging, mobile,...
# 6            2013.0
# 7               NaN  opensource, e-commerce, ecommerce, magento, op...
# 8               NaN
# 9               NaN  firststring, high-school-sports, high-school-a...
# 10              NaN  social, calendar, venue, directory, event, sof...
# 11              NaN  marketing-technology, marketing-software, medi...
# 12              NaN  interest-graph, personalized-commerce, ecommer...
# 13              NaN  frequent-flyer, frequent-flier, loyalty-progra...
# 14              NaN                         mobile, widgets, flyscreen
# 15              NaN           kids, learning, games, operating, system
# 16              NaN  social, calendar, venue, directory, event, sof...
# 17              NaN  marketing-technology, marketing-software, medi...
# 18              NaN  interest-graph, personalized-commerce, ecommer...
# 19              NaN  frequent-flyer, frequent-flier, loyalty-progra...
# 20              NaN                         mobile, widgets, flyscreen
# 21              NaN           kids, learning, games, operating, system
# 22              NaN                                       facebook-app
# 23              NaN  web-2-0, semantic-search, mobile, developer, a...
# 24              NaN  new-york, nyc, sales, deals, shopping, dining,...
# 25              NaN  rfid, gps, independent-elder-care, security, l...
# 26              NaN  ireland, mobile-application-platform, open-sta...
# 27              NaN                                               None
# 28           2012.0  twitter, social, ecommerce, gaming, virtual-go...
# 29              NaN
# 30              NaN                              cloud, enterprise, it
# 31              NaN         social-media-advertising, twitter, youtube
# 32           2013.0           china, social-network, sns, study-abroad
# 33           2013.0  betaspring, jobs, college, college-jobs, stude...
# 34              NaN                                               None
# 35              NaN  social, consumer-products, digital, photo, exp...
# 36              NaN  big-data, predictive-analytics, social-data, l...
# 37              NaN
# 38              NaN  fashion, sharing, tastes, behavior, style, str...
# 39              NaN
# 40              NaN  ticketea, ticketing, event, management, invita...
# 41              NaN          dentist-philadelphia, doctor-appointments
#
#                                  description total_money_raised
# 0                  Equity-based Crowdfunding                $9M
# 1                Cloud Publishing for Mobile              $7.1M
# 2                     Tech Support Community                $8M
# 3                    Global Social Discovery                €3M
# 4                    online ticket reselling             $58.8M
# 5             photos social mobile messaging                $4M
# 6                                                           $6M
# 7                         eCommerce Platform             $22.5M
# 8                Visual Search for ecommerce                £3M
# 9              Prep Sports Hyperlocal Search              $200k
# 10         Blackboard for Student Activities              $300k
# 11     Marketing Software and Media Services             $34.8M
# 12  Interest Graph Personalization/Analytics              $930k
# 13            Award+Cash Travel Meta Search              $3.27M
# 14                                                        $750k
# 15                                                        $200k
# 16         Blackboard for Student Activities              $300k
# 17     Marketing Software and Media Services             $34.8M
# 18  Interest Graph Personalization/Analytics              $930k
# 19            Award+Cash Travel Meta Search              $3.27M
# 20                                                        $750k
# 21                                                        $200k
# 22                    Mobile social commerce                $2M
# 23                     visual learning robot                $2M
# 24                    Every deal. One place.             $7.55M
# 25                                                        $650k
# 26               Mobile Application Platform                $9M
# 27                                                       $4.03M
# 28             Easy, secure social payments.              $500k
# 29                       Multimedia Software              $3.1M
# 30                 IT Performance Management             $55.8M
# 31   Advertising platform for the people web             $6.23M
# 32                       Chinese student SNS                $6M
# 33                       College Job Network               $30k
# 34                                                        £865k
# 35                                                         $59k
# 36             Predictive Analytics Platform             $6.79M
# 37                 Mexican cleantech company               $20M
# 38                  Street fashion community              $800k
# 39         Pluripotent stem cell technology              $41.3M
# 40          Online event management platform             $5.73M
# 41    Online doctor and dentist appointments              $800k

# %% [markdown]
# ## APIs

# %%
import os
from dotenv import load_dotenv
import requests
load_dotenv()
# Out:
# True

# %%
def googleRequestAuthorized():

    # Function
    authToken = os.getenv("GOOGLE_API_TOKEN")
    if not authToken:
        raise ValueError("NECESITAS UN TOKEN")
    url = "https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key={}".format(authToken)

    res = requests.get(url)
    data = res.json()
    return data

# %%
example = googleRequestAuthorized()

# %%
print(example)
# Out:
# {'results': [{'address_components': [{'long_name': '1600', 'short_name': '1600', 'types': ['street_number']}, {'long_name': 'Amphitheatre Parkway', 'short_name': 'Amphitheatre Pkwy', 'types': ['route']}, {'long_name': 'Mountain View', 'short_name': 'Mountain View', 'types': ['locality', 'political']}, {'long_name': 'Santa Clara County', 'short_name': 'Santa Clara County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'California', 'short_name': 'CA', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '94043', 'short_name': '94043', 'types': ['postal_code']}], 'formatted_address': '1600 Amphitheatre Pkwy, Mountain View, CA 94043, USA', 'geometry': {'location': {'lat': 37.4210596, 'lng': -122.0847774}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 37.4224085802915, 'lng': -122.0834284197085}, 'southwest': {'lat': 37.4197106197085, 'lng': -122.0861263802915}}}, 'place_id': 'ChIJtYuu0V25j4ARwu5e4wwRYgE', 'plus_code': {'compound_code': 'CWC8+R7 Mountain View, California, United States', 'global_code': '849VCWC8+R7'}, 'types': ['street_address']}], 'status': 'OK'}
